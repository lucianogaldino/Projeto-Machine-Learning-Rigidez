# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd

# %% [markdown]
# # Análises iniciais

# %%
rigidez = pd.read_table('mola.txt')

# %%
rigidez.head()
# Out:
#    cargas  forca    Lo     L       x      K
# 0       1   0.23  27.0  34.0  0.0070  32.86
# 1       2   0.45  27.0  41.4  0.0144  31.25
# 2       3   0.55  27.0  44.2  0.0172  31.98
# 3       4   0.68  27.0  47.2  0.0202  33.66
# 4       5   0.72  27.0  50.0  0.0230  31.30

# %%
rigidez.head(20)
# Out:
#     cargas  forca    Lo       L        x      K
# 0        1   0.23  27.0   34.00  0.00700  32.86
# 1        2   0.45  27.0   41.40  0.01440  31.25
# 2        3   0.55  27.0   44.20  0.01720  31.98
# 3        4   0.68  27.0   47.20  0.02020  33.66
# 4        5   0.72  27.0   50.00  0.02300  31.30
# 5        6   0.83  27.0   51.90  0.02490  33.33
# 6        7   1.21  27.0   66.00  0.03900  31.03
# 7        8   1.23  27.0   66.30  0.03930  31.30
# 8        9   1.35  27.0   69.30  0.04230  31.91
# 9       10   1.71  27.0   82.50  0.05550  30.81
# 10      11   1.75  27.0   83.80  0.05680  30.81
# 11      12   1.92  27.0   91.70  0.06470  29.68
# 12      13   2.04  27.0   94.60  0.06760  30.18
# 13      14   2.15  27.0   97.40  0.07040  30.54
# 14      15   2.19  27.0   98.50  0.07150  30.63
# 15      16   2.25  27.0   99.74  0.07274  30.93
# 16      17   2.40  27.0  105.50  0.07850  30.57
# 17      18   2.55  27.0  108.20  0.08120  31.40
# 18      19   2.72  27.0  112.30  0.08530  31.89
# ...

# %%
rigidez.describe()
# Out:
#          cargas      forca    Lo           L          x          K
# count  20.00000  20.000000  20.0   20.000000  20.000000  20.000000
# mean   10.50000   1.589000  27.0   78.202000   0.051202  31.343500
# std     5.91608   0.815242   0.0   26.696167   0.026696   1.016952
# min     1.00000   0.230000  27.0   34.000000   0.007000  29.680000
# 25%     5.75000   0.802500  27.0   51.425000   0.024425  30.765000
# 50%    10.50000   1.730000  27.0   83.150000   0.056150  31.140000
# 75%    15.25000   2.205000  27.0   98.810000   0.071810  31.895000
# max    20.00000   2.850000  27.0  119.500000   0.092500  33.660000

# %%
rigidez.shape
# Out:
# (20, 6)

# %%
rigidez.forca.hist(bins=10)
plt.xlabel('Força(N)')
plt.ylabel('Rigidez(N/m)')
plt.title('Rigidez da mola')
plt.show()

# %%
x = rigidez.x
y = rigidez.forca
plt.scatter(x, y)
plt.xlabel('Deformação(mm)')
plt.ylabel('Força(N)')
plt.title('Rigidez da mola')
plt.grid(True)
plt.show()
